# %% [markdown]
# ## Generating the Agent graph flowchart

# %%
# # Import from your agent_graph module
# from agent_graph import save_graph_image

# # Save the graph as PNG - it will be created in the current folder
# save_graph_image("agent_graph_flow.png")

# # Display the image in the notebook
# from IPython.display import Image
# Image(filename="agent_graph_flow.png")

# %%
# visualize_graph.ipynb
# Put this in your main project folder (Nigeria_Tax_Assistance_Agent/)

import sys
import os

# Add the tax_engine folder to Python path
sys.path.append(os.path.join(os.getcwd(), "ai_engine/tax_engine"))

# Now import
from agent_graph import build_graph
from IPython.display import Image

# Build the graph
graph = build_graph()

# Save and display
try:
    # Save as PNG in current folder
    graph.get_graph().draw_mermaid_png(output_file_path="tax_agent_flow.png")
    
    # Display it
    display(Image(filename="tax_agent_flow.png"))
    print("✅ Graph saved as 'tax_agent_flow.png' in current folder")
    
except Exception as e:
    print(f"❌ Error: {e}")
    print("\nPlease install these packages:")
    print("pip install pygraphviz")
    print("\nAnd install graphviz on your system:")
    print("- macOS: brew install graphviz")
    print("- Ubuntu: sudo apt-get install graphviz")
    print("- Windows: Download from https://graphviz.org/download/")
